# %%
import pandas as pd
import numpy as np

# %%
df2 = pd.read_csv("/Users/raghav/Downloads/campaign_data.csv")

# %%
df2
# Out:
#        default housing loan    contact month day_of_week  duration  campaign  \
# 0           no      no   no  telephone   may         mon       261         1
# 1      unknown      no   no  telephone   may         mon       149         1
# 2           no     yes   no  telephone   may         mon       226         1
# 3           no      no   no  telephone   may         mon       151         1
# 4           no      no  yes  telephone   may         mon       307         1
# ...        ...     ...  ...        ...   ...         ...       ...       ...
# 41183       no     yes   no   cellular   nov         fri       334         1
# 41184       no      no   no   cellular   nov         fri       383         1
# 41185       no     yes   no   cellular   nov         fri       189         2
# 41186       no      no   no   cellular   nov         fri       442         1
# 41187       no     yes   no   cellular   nov         fri       239         3
#
# ...

# %%
# Assuming df2 is already defined
df2['Savings_Account'] = np.random.randint(0, 2, size=len(df2))
df2['Credit_Card'] = np.random.randint(0, 2, size=len(df2))
df2['Debit_Card'] = np.random.randint(0, 2, size=len(df2))
df2['y'] = df2['y'].replace({'yes': 1, 'no': 0})
df2.rename(columns={'y': 'Term_Deposit'}, inplace=True)

# %%
df2
# Out:
#        default housing loan    contact month day_of_week  duration  campaign  \
# 0           no      no   no  telephone   may         mon       261         1
# 1      unknown      no   no  telephone   may         mon       149         1
# 2           no     yes   no  telephone   may         mon       226         1
# 3           no      no   no  telephone   may         mon       151         1
# 4           no      no  yes  telephone   may         mon       307         1
# ...        ...     ...  ...        ...   ...         ...       ...       ...
# 41183       no     yes   no   cellular   nov         fri       334         1
# 41184       no      no   no   cellular   nov         fri       383         1
# 41185       no     yes   no   cellular   nov         fri       189         2
# 41186       no      no   no   cellular   nov         fri       442         1
# 41187       no     yes   no   cellular   nov         fri       239         3
#
# ...

# %%
df2.to_csv("/Users/raghav/Desktop/Apexon/Product_Marketing_Campaign/Updated_Product_Targeting_Data.csv")
